# %% [markdown]
# <h1 style="text-align: center;">Análisis exploratorio de los datos</h1>
# <h2 style="text-align: center;">Camilo Esteban Zambrano Pereira</h2>
# <h2 style="text-align: center;">Visión de máquina</h2>

# %% [markdown]
# # Librerias
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import numpy as np
import seaborn as sns
sns.set(rc={'figure.figsize':(15,10)})
import cv2
from tqdm import tqdm
import os
import glob

# %% [markdown]
# # Carga de datos
# ---

# %%
df = pd.read_csv("../../data/train.csv")
df
# Out:
#                               id        class segmentation
# 0       case123_day20_slice_0001  large_bowel          NaN
# 1       case123_day20_slice_0001  small_bowel          NaN
# 2       case123_day20_slice_0001      stomach          NaN
# 3       case123_day20_slice_0002  large_bowel          NaN
# 4       case123_day20_slice_0002  small_bowel          NaN
# ...                          ...          ...          ...
# 115483    case30_day0_slice_0143  small_bowel          NaN
# 115484    case30_day0_slice_0143      stomach          NaN
# 115485    case30_day0_slice_0144  large_bowel          NaN
# 115486    case30_day0_slice_0144  small_bowel          NaN
# 115487    case30_day0_slice_0144      stomach          NaN
#
# [115488 rows x 3 columns]

# %% [markdown]
# # Análisis exploratorio
# ---

# %% [markdown]
# El dataset contiene las siguientes columnas:
# * id: Contiene el caso, el día y el número de imágen.
# * segmentation: para algunas imágenes, se describe la mascara que segmenta algun organo en especifico.
# * class: Organo que se esta segmentando.

# %% [markdown]
# Usando la funciones basicas de pandas se puede observar que:
# * Existen 3 clases, "large_bowel", "small_bowel"  y "stomach", que representan al intestino grueso, intestino delgado, y el estomago respectivamente,
# * El dataset contiene 115.488 datos, de los cuales existen 38.496 ids unicos, esto se debe a que para cada imágen hay 3 organos segmentados.

# %%
df.describe()
# Out:
#                               id        class  \
# count                     115488       115488
# unique                     38496            3
# top     case123_day20_slice_0001  large_bowel
# freq                           3        38496
#
#                                              segmentation
# count                                               33913
# unique                                              33899
# top     12629 10 12894 12 13158 15 13423 17 13688 19 1...
# freq                                                    2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115488 entries, 0 to 115487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            115488 non-null  object
#  1   class         115488 non-null  object
#  2   segmentation  33913 non-null   object
# dtypes: object(3)
# memory usage: 2.6+ MB

# %%
df["class"].unique()
# Out:
# array(['large_bowel', 'small_bowel', 'stomach'], dtype=object)

# %% [markdown]
# Descomponiendo la información suministrada por el id, se puede encontrar información sobre el número de casos, número de días, y la cantidad de imágenes por cada caso:

# %% [markdown]
# Adicionalmente, en el nombre de los archivos se encuentra información sobre el alto y ancho en pixeles, y el espaciado entre pixeles en milimetros.
# ![image.png](attachment:image.png)
#
#
# A continuación se extrae la información del tamaño y se añade al dataset.

# %%
def parse_int(s):
    i = j = 0
    while i < len(s):
        while j < len(s) and s[j].isdigit():
            j += 1
        if i < j:
            return int(s[i:j])
        i = j = j + 1
    return math.nan

def extract_image_info(path):
    case_day, fname = path.rsplit("\\", maxsplit=3)[1::2]
    case, day = case_day.split("_")
    slice, height, width = fname.split("_", maxsplit=4)[1:4]
    info = [f"{case}_{day}_slice_{slice}"]
    numeric_info = [case, day, slice, height, width]
    info.extend([parse_int(info) for info in numeric_info])
    return info
    
def create_image_df(path):
    paths = glob.glob(f"{TRAIN_DIR}/**/*.png", recursive=True)
    df = pd.DataFrame({"path": paths})
    info_cols = ["id", "case", "day", "slice", "height", "width"]
    df[info_cols] = df.apply(
        lambda row: extract_image_info(row.path), 
        axis=1,
        result_type="expand"
    )
    return df

TRAIN_DIR = "../../data/train"
data = create_image_df(TRAIN_DIR)
data
# Out:
#                                                     path  \
# 0      ../../data/train\case101\case101_day20\scans\s...
# 1      ../../data/train\case101\case101_day20\scans\s...
# 2      ../../data/train\case101\case101_day20\scans\s...
# 3      ../../data/train\case101\case101_day20\scans\s...
# 4      ../../data/train\case101\case101_day20\scans\s...
# ...                                                  ...
# 38491  ../../data/train\case92\case92_day0\scans\slic...
# 38492  ../../data/train\case92\case92_day0\scans\slic...
# 38493  ../../data/train\case92\case92_day0\scans\slic...
# 38494  ../../data/train\case92\case92_day0\scans\slic...
# 38495  ../../data/train\case92\case92_day0\scans\slic...
#
#                              id  case  day  slice  height  width
# 0      case101_day20_slice_0001   101   20      1     266    266
# 1      case101_day20_slice_0002   101   20      2     266    266
# 2      case101_day20_slice_0003   101   20      3     266    266
# 3      case101_day20_slice_0004   101   20      4     266    266
# 4      case101_day20_slice_0005   101   20      5     266    266
# ...                         ...   ...  ...    ...     ...    ...
# 38491    case92_day0_slice_0140    92    0    140     266    266
# 38492    case92_day0_slice_0141    92    0    141     266    266
# 38493    case92_day0_slice_0142    92    0    142     266    266
# 38494    case92_day0_slice_0143    92    0    143     266    266
# 38495    case92_day0_slice_0144    92    0    144     266    266
#
# [38496 rows x 7 columns]

# %% [markdown]
# De la siguiente grafica se puede observar que el caso más extenso es el 36, pues este cuente con un mayor número de imágenes. Además, existen casos faltantes que se deben a que el dataset es el destinado a entrenamiento ofrecido por kaggle.

# %%
ax = sns.countplot(x="case", data=data)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Agrupando el dataset por casos se observa que se cuenta con 85 pacientes junto con el día en el que se tomo la tomografía final

# %%
data_case = data.groupby(['case']).max()
data_case.head()
# Out:
#                                                    path  \
# case
# 2     ../../data/train\case2\case2_day5\scans\slice_...
# 6     ../../data/train\case6\case6_day24\scans\slice...
# 7     ../../data/train\case7\case7_day19\scans\slice...
# 9     ../../data/train\case9\case9_day22\scans\slice...
# 11    ../../data/train\case11\case11_day13\scans\sli...
#
#                            id  day  slice  height  width
# case
# 2       case2_day5_slice_0144    5    144     266    266
# 6      case6_day24_slice_0144   24    144     360    310
# 7      case7_day19_slice_0144   19    144     266    266
# 9      case9_day22_slice_0144   22    144     360    310
# 11    case11_day13_slice_0144   13    144     360    310

# %% [markdown]
# En cuanto a la cantidad de imagenes, se observa que la mayoría de casos cuentan con 144 imágenes por día.

# %%
ax = sns.countplot(x="slice", data=data_case)
ax.tick_params(axis='x', rotation=90)

# %% [markdown]
# Solamente el caso 34 - día 16 suenta con 80 imagenes

# %%
data_case[data_case["slice"] == 80]
# Out:
#                                                    path  \
# case
# 34    ../../data/train\case34\case34_day16\scans\sli...
#
#                            id  day  slice  height  width
# case
# 34    case34_day16_slice_0080   16     80     276    276

# %% [markdown]
# Agrupando el dataset por id, es posible encontrar información sobre las dimenciones de las imágenes.

# %%
data_images = data.groupby(['id']).max()
data_images
# Out:
#                                                                        path  \
# id
# case101_day20_slice_0001  ../../data/train\case101\case101_day20\scans\s...
# case101_day20_slice_0002  ../../data/train\case101\case101_day20\scans\s...
# case101_day20_slice_0003  ../../data/train\case101\case101_day20\scans\s...
# case101_day20_slice_0004  ../../data/train\case101\case101_day20\scans\s...
# case101_day20_slice_0005  ../../data/train\case101\case101_day20\scans\s...
# ...                                                                     ...
# case9_day22_slice_0140    ../../data/train\case9\case9_day22\scans\slice...
# case9_day22_slice_0141    ../../data/train\case9\case9_day22\scans\slice...
# case9_day22_slice_0142    ../../data/train\case9\case9_day22\scans\slice...
# case9_day22_slice_0143    ../../data/train\case9\case9_day22\scans\slice...
# case9_day22_slice_0144    ../../data/train\case9\case9_day22\scans\slice...
#
#                           case  day  slice  height  width
# id
# case101_day20_slice_0001   101   20      1     266    266
# case101_day20_slice_0002   101   20      2     266    266
# case101_day20_slice_0003   101   20      3     266    266
# case101_day20_slice_0004   101   20      4     266    266
# case101_day20_slice_0005   101   20      5     266    266
# ...                        ...  ...    ...     ...    ...
# case9_day22_slice_0140       9   22    140     360    310
# case9_day22_slice_0141       9   22    141     360    310
# case9_day22_slice_0142       9   22    142     360    310
# case9_day22_slice_0143       9   22    143     360    310
# case9_day22_slice_0144       9   22    144     360    310
#
# [38496 rows x 6 columns]

# %% [markdown]
# Tamaños de la altura de la imagen

# %%
data_images.height.value_counts()
# Out:
# 266    25920
# 360    11232
# 276     1200
# 234      144
# Name: height, dtype: int64

# %% [markdown]
# Tanaños del ancho de la imagen

# %%
data_images.width.value_counts()
# Out:
# 266    25920
# 310    11232
# 276     1200
# 234      144
# Name: width, dtype: int64

# %% [markdown]
# Del dataset se observa que hay una misma cantidad de imagenes con determinadas dimensiones, a partir de esto, se puede establecer que los tamaños son:
# * 266px x 266px
# * 360px x 310px
# * 276px x 276px
# * 432px x 432px
#
# De las graficas se puede observar que la aproximadamente el tamaño que predomina es de 266px x 266px, seguido por 360px x 310px.

# %%
fig, axes = plt.subplots(1, 2)
sns.countplot(ax=axes[0],x="height", data=data_images)
sns.countplot(ax=axes[1],x="width", data=data_images)
# Out:
# <AxesSubplot:xlabel='width', ylabel='count'>

# %% [markdown]
# Para analizar la segmentación, por facilidad se modifica el dataset para tener ids unicos:

# %%
def create_mask_df(df):
    df = df.set_index(["id", "class"]).unstack().reset_index()
    df.columns = "id", 'large_bowel', 'small_bowel', 'stomach'
    df.fillna("", inplace=True)
    return df

segmentation = create_mask_df(df)
data = segmentation.merge(data, on="id", how="left")
data.head()
# Out:
#                          id large_bowel small_bowel stomach  \
# 0  case101_day20_slice_0001
# 1  case101_day20_slice_0002
# 2  case101_day20_slice_0003
# 3  case101_day20_slice_0004
# 4  case101_day20_slice_0005
#
#                                                 path  case  day  slice  \
# 0  ../../data/train\case101\case101_day20\scans\s...   101   20      1
# 1  ../../data/train\case101\case101_day20\scans\s...   101   20      2
# 2  ../../data/train\case101\case101_day20\scans\s...   101   20      3
# 3  ../../data/train\case101\case101_day20\scans\s...   101   20      4
# 4  ../../data/train\case101\case101_day20\scans\s...   101   20      5
#
#    height  width
# 0     266    266
# 1     266    266
# 2     266    266
# 3     266    266
# 4     266    266

# %% [markdown]
# Tomando las imágenes que estan segmentadas:

# %%
segment = data[(data["large_bowel"] != "") | (data["small_bowel"] != "") | (data["stomach"] != "")]
segment.head()
# Out:
#                           id large_bowel small_bowel  \
# 65  case101_day20_slice_0066
# 66  case101_day20_slice_0067
# 67  case101_day20_slice_0068
# 68  case101_day20_slice_0069
# 69  case101_day20_slice_0070
#
#                                               stomach  \
# 65  32107 5 32371 10 32635 13 32900 15 33165 17 33...
# 66  31313 2 31577 7 31841 10 32105 14 32369 17 326...
# 67  30517 2 30781 6 31046 9 31311 11 31575 15 3184...
# 68  29981 10 30246 13 30511 16 30776 19 31041 21 3...
# 69  28918 9 29182 14 29446 18 29711 21 29976 23 30...
#
#                                                  path  case  day  slice  \
# 65  ../../data/train\case101\case101_day20\scans\s...   101   20     66
# 66  ../../data/train\case101\case101_day20\scans\s...   101   20     67
# 67  ../../data/train\case101\case101_day20\scans\s...   101   20     68
# 68  ../../data/train\case101\case101_day20\scans\s...   101   20     69
# 69  ../../data/train\case101\case101_day20\scans\s...   101   20     70
#
#     height  width
# 65     266    266
# 66     266    266
# 67     266    266
# 68     266    266
# 69     266    266

# %% [markdown]
# En total se tienen 16.590 imagenes segmentadas

# %%
segment.shape[0]
# Out:
# 16590

# %% [markdown]
# Las máscaras se encuentran codificadas en RLE-encoded, se hace la función que la decodifica y se toman n muestras aleatorias del dataset, se generan las máscaras y se segmenta la imágen:

# %%
def generate_mask(seg, shape):
    if seg == "":
        mask = np.zeros(np.prod(shape), dtype=np.uint8)
        return mask
    start_list = seg[0::2]
    length_list = seg[1::2]

    mask = np.zeros(np.prod(shape), dtype=np.uint8)

    for start, length in zip(start_list, length_list):
        start = int(start)
        length = int(length)
        mask[start:start + length] = 255

    mask = np.reshape(mask, shape)
    mask = np.ma.masked_where(mask == 0, mask)
    
    return mask

def get_random_mask(df, n):
    mask_colors = [(1, 0, 0), (0, 1, 0), (0, 0, 1)]
    legend_colors = [Rectangle((0,0),1,1, color=color) for color in mask_colors]
    labels = ["Large Bowel", "Small Bowel", "Stomach"]
    for i in range(n):
        sample = df.sample()
        ids = sample.iloc[0,0].split("_")
        path = sample["path"].iloc[0]
        img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
        
        mask1 = generate_mask(sample.iloc[0, 1].split(), (sample["width"].iloc[0], sample["height"].iloc[0]))
        mask2 = generate_mask(sample.iloc[0, 2].split(), (sample["width"].iloc[0], sample["height"].iloc[0]))
        mask3 = generate_mask(sample.iloc[0, 3].split(), (sample["width"].iloc[0], sample["height"].iloc[0]))
        
        plt.figure()
        fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
        ax1.imshow(img, cmap='binary')
        ax1.set_title("Original - " + " - ".join(ids))
        
        ax2.imshow(mask1, cmap='autumn')
        ax2.imshow(mask2, cmap='summer')
        ax2.imshow(mask3, cmap='winter')
        ax2.set_title("Mascaras")
        ax2.legend(legend_colors, labels)
        
        ax3.imshow(img, cmap='binary')
        ax3.imshow(mask1, interpolation='none', cmap='autumn', alpha=0.5)
        ax3.imshow(mask2, interpolation='none', cmap='summer', alpha=0.5)
        ax3.imshow(mask3, interpolation='none', cmap='winter', alpha=0.5)
        ax3.set_title("Segmentación")
        
        ax1.axis("off")
        ax2.axis("off")
        ax3.axis("off")

# %%
get_random_mask(segment, 10)
# Out:
# c:\Users\camsp\anaconda3\lib\site-packages\matplotlib\image.py:443: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# c:\Users\camsp\anaconda3\lib\site-packages\matplotlib\image.py:444: UserWarning: Warning: converting a masked element to nan.
#   vmid = np.float64(self.norm.vmin) + dv / 2
